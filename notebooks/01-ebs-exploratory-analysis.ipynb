# %%
import pandas as pd

# %%
# Data file path constants
DATA_DIR = "./data"
CUSTOMERS_FILE = "../data/olist_customers_dataset.csv"
GEOLOCATION_FILE = "../data/olist_geolocation_dataset.csv"
ORDER_ITEMS_FILE = "../data/olist_order_items_dataset.csv"
ORDER_PAYMENTS_FILE = "../data/olist_order_payments_dataset.csv"
ORDER_REVIEWS_FILE = "../data/olist_order_reviews_dataset.csv"
ORDERS_FILE = "../data/olist_orders_dataset.csv"
PRODUCTS_FILE = "../data/olist_products_dataset.csv"
SELLERS_FILE = "../data/olist_sellers_dataset.csv"
PRODUCT_CATEGORY_TRANSLATION_FILE = (
    "../data/product_category_name_translation.csv"
)


def read_csvs_from_data(file_path: str) -> pd.DataFrame:
    """Read a CSV file from the given path and return as a dataframe."""
    return pd.read_csv(file_path)


def merge_ecommerce_data() -> pd.DataFrame:
    """
    Read and merge orders, items, products, and reviews dataframes.

    Returns a merged dataframe with all relevant information.
    """
    orders = read_csvs_from_data(ORDERS_FILE)
    items = read_csvs_from_data(ORDER_ITEMS_FILE)
    products = read_csvs_from_data(PRODUCTS_FILE)
    reviews = read_csvs_from_data(ORDER_REVIEWS_FILE)

    # Merge orders with items
    merged = orders.merge(items, on="order_id", how="left")

    # Merge with products
    merged = merged.merge(products, on="product_id", how="left")

    # Merge with reviews
    merged = merged.merge(reviews, on="order_id", how="left")

    return merged


df = merge_ecommerce_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114092 entries, 0 to 114091
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       114092 non-null  object
#  1   customer_id                    114092 non-null  object
#  2   order_status                   114092 non-null  object
#  3   order_purchase_timestamp       114092 non-null  object
#  4   order_approved_at              113930 non-null  object
#  5   order_delivered_carrier_date   112112 non-null  object
#  6   order_delivered_customer_date  110839 non-null  object
#  7   order_estimated_delivery_date  114092 non-null  object
#  8   order_item_id                  113314 non-null  float64
#  9   product_id                     113314 non-null  object
#  10  seller_id                      113314 non-null  object
#  11  shipping_limit_date            113314 non-null  object
#  12  price                          113314 non-null  float64
#  13  freight_value                  113314 non-null  float64
#  14  product_category_name          111702 non-null  object
#  15  product_name_lenght            111702 non-null  float64
#  16  product_description_lenght     111702 non-null  float64
#  17  product_photos_qty             111702 non-null  float64
#  18  product_weight_g               113296 non-null  float64
#  19  product_length_cm              113296 non-null  float64
#  20  product_height_cm              113296 non-null  float64
#  21  product_width_cm               113296 non-null  float64
#  22  review_id                      113131 non-null  object
#  23  review_score                   113131 non-null  float64
#  24  review_comment_title           13523 non-null   object
#  25  review_comment_message         48166 non-null   object
#  26  review_creation_date           113131 non-null  object
#  27  review_answer_timestamp        113131 non-null  object
# dtypes: float64(11), object(17)
# memory usage: 24.4+ MB

# %%
df2 = df.dropna()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11181 entries, 1 to 114076
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       11181 non-null  object
#  1   customer_id                    11181 non-null  object
#  2   order_status                   11181 non-null  object
#  3   order_purchase_timestamp       11181 non-null  object
#  4   order_approved_at              11181 non-null  object
#  5   order_delivered_carrier_date   11181 non-null  object
#  6   order_delivered_customer_date  11181 non-null  object
#  7   order_estimated_delivery_date  11181 non-null  object
#  8   order_item_id                  11181 non-null  float64
#  9   product_id                     11181 non-null  object
#  10  seller_id                      11181 non-null  object
#  11  shipping_limit_date            11181 non-null  object
#  12  price                          11181 non-null  float64
#  13  freight_value                  11181 non-null  float64
#  14  product_category_name          11181 non-null  object
#  15  product_name_lenght            11181 non-null  float64
#  16  product_description_lenght     11181 non-null  float64
#  17  product_photos_qty             11181 non-null  float64
#  18  product_weight_g               11181 non-null  float64
#  19  product_length_cm              11181 non-null  float64
#  20  product_height_cm              11181 non-null  float64
#  21  product_width_cm               11181 non-null  float64
#  22  review_id                      11181 non-null  object
#  23  review_score                   11181 non-null  float64
#  24  review_comment_title           11181 non-null  object
#  25  review_comment_message         11181 non-null  object
#  26  review_creation_date           11181 non-null  object
#  27  review_answer_timestamp        11181 non-null  object
# dtypes: float64(11), object(17)
# memory usage: 2.5+ MB
